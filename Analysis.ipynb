# %% [markdown]
# <h1> Job  Analysis </h1>
#
# ## Objective
# The objective of this project is to analyze job postings data and identify trends in:
#
# - Job categories
# - Hiring locations
# - Companies hiring the most candidates
# - Job types
# - Hiring trends over time
# - Most demanded skills
#
# The analysis is performed using:
# - Pandas for data manipulation
# - Matplotlib for data visualization

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datasets

# %% [markdown]
# # Loading The Dataset

# %%
data = datasets.load_dataset("azrai99/job-dataset")

# %%
job  = data['train'].to_pandas()
job.head()
# Out:
#      job_id                                     job_title  \
# 0  74630583              Procurement Executive (Contract)
# 1  74660602                  Account Executive/ Assistant
# 2  74655679  Data Analyst - Asset Management, SPX Express
# 3  74657624                              Service Engineer
# 4  74679363                          Purchasing Executive
#
#                                   company  \
# 0   Coca-Cola Bottlers (Malaysia) Sdn Bhd
# 1      Acoustic & Lighting System Sdn Bhd
# 2          Shopee Mobile Malaysia Sdn Bhd
# 3             Sun Medical Systems Sdn Bhd
# 4  Magnet Security & Automation Sdn. Bhd.
#
#                                         descriptions         location  \
# 0  Position Purpose\nManage aspects of procuremen...  Negeri Sembilan
# 1  We are looking for a Account Executive/ Assist...         Petaling
# 2  Performs detailed data analysis on existing sp...   Klang District
# 3  You are important for troubleshooting, install...         Petaling
# ...

# %% [markdown]
# # Dataset Overview

# %%
job.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 59306 entries, 0 to 59305
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_id        59306 non-null  int64
#  1   job_title     59306 non-null  str
#  2   company       59306 non-null  str
#  3   descriptions  59306 non-null  str
#  4   location      59306 non-null  str
#  5   category      59306 non-null  str
#  6   subcategory   59306 non-null  str
#  7   role          57370 non-null  str
#  8   type          59306 non-null  str
#  9   salary        26641 non-null  str
#  10  listingDate   59306 non-null  str
# dtypes: int64(1), str(10)
# memory usage: 121.4 MB

# %% [markdown]
# # Question 1
#
# ## Which job categories have the highest number of job openings?
#
# This analysis helps identify industries with the greatest hiring demand.

# %%
top_categories = job['category'].value_counts().head(10)
plt.figure(figsize=(15,8))
plt.bar(top_categories.index, top_categories.values)
plt.xticks(rotation=45, ha='right')
plt.title("Top 10 Job Categories")
plt.xlabel("Category")
plt.ylabel("Number of Jobs")
plt.show()

# %% [markdown]
# # Question 2
#
# ## Which locations have the highest number of job opportunities?
#
# This helps identify major employment hubs.

# %%
top_locations = job['location'].value_counts().head(10)

plt.figure(figsize=(12,6))
plt.bar(top_locations.index, top_locations.values)
plt.xticks(rotation=45, ha='right')
plt.title("Top Hiring Locations")
plt.xlabel("Location")
plt.ylabel("Number of Jobs")

plt.show()

# %% [markdown]
# # Question 3
#
# ## What is the distribution of job types?
#
# This analysis shows the proportion of Full-Time, Part-Time, Contract, and Internship positions.

# %%
job_types = job['type'].value_counts()

plt.figure(figsize=(85,5))

plt.pie(
    job_types,
    labels=job_types.index,
    autopct='%1.1f%%',
    normalize=True
)


plt.title("Job Type Distribution")

plt.show()

# %% [markdown]
# # Question 4
#
# ## Which companies are posting the most job opportunities?

# %%
top_companies = job['company'].value_counts().head(15)

plt.figure(figsize=(12,6))
top_companies.plot(kind='bar')

plt.title("Top Hiring Companies")
plt.xlabel("Company")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Question 5
#
# ## Which job titles appear most frequently?
#
# This helps identify roles that are currently in high demand.

# %%
top_jobs = (
    job['job_title']
    .value_counts()
    .head(20)
    .sort_values(ascending=True)
)

plt.figure(figsize=(10,6))

plt.barh(top_jobs.index, top_jobs.values)

plt.title("Most Common Job Titles")
plt.xlabel("Number of Jobs")
plt.ylabel("Job Title")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 6
#
# ## How has hiring activity changed over time?

# %%
job['listingDate'] = pd.to_datetime(job['listingDate'])
monthly_jobs = job.groupby(
    job['listingDate'].dt.to_period('M')
).size()
plt.figure(figsize=(10,5))
monthly_jobs.plot()
plt.title("Monthly Hiring Trend")
plt.xlabel("Month")
plt.ylabel("Number of Jobs")
plt.show()
# Out:
# C:\Users\Aditya Verma\AppData\Local\Temp\ipykernel_4796\503385149.py:3: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   job['listingDate'].dt.to_period('M')

# %% [markdown]
# # Conclusion
#
# This Analysis explored job market trends using real-world job posting data.
#
# Using Pandas and Matplotlib, we analyzed:
#
# - Industry demand
# - Hiring locations
# - Recruitment activity
# - Job roles
# - Skill requirements
# - Hiring trends
#
# The insights can help job seekers understand market requirements and make informed career decisions.
